# %%
import numpy as np
from sklearn.model_selection import train_test_split

# from naive_bayes import NaiveBayes

# %%
dataset = np.loadtxt("./data/play_tennis_dataset.csv", delimiter=',', dtype=str)
random = np.random.randint(0, dataset.shape[0])
X, y = dataset[random:random+10, 1:-1], dataset[random:random+10, -1]

print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
# Out:
# Shape of X: (10, 4)
# Shape of y: (10,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=True, random_state=1
)

# %%
class NaiveBayes:
    def __init__(self):
        self.X = None
        self.y = None
        self.x_values = {}
        self.y_values = []
    
    def fit(self, X: np.ndarray, y: np.ndarray):
        self.X = X
        self.y = y
        
        for j in range(self.X.shape[1]):
            self.x_values[j] = np.unique(self.X[:, j])
        
        self.y_values = np.unique(y)
        
        print(self.x_values)
        print(self.y_values)
        
    def predict(self, x: np.ndarray) -> int:
        for i in range(X.shape[0]):
            if X[i] == x:
                return y[i]
        
        _, cols = x.shape
        
        positive_proba = 0
        negative_proba = 0
        
        
        return 1 if positive_proba > negative_proba else 0

# %%
nb = NaiveBayes()
