# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

from knn import KNN

# %%
X, y = load_iris(return_X_y=True)

print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
# Out:
# Shape of X: (150, 4)
# Shape of y: (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.2, 
    shuffle=True, 
    random_state=42
)

# %%
knn = KNN(k=6)
knn.fit(X_train, y_train)

# %%
y_hat = []
for i in range(len(X_test)):
    y_hat.append(knn.predict(X_test[i]))
    print(f"Predicted value: {y_hat[i]}, expected value: {y_test[i]}, correct: {y_hat[i] == y_test[i]}")
# Out:
# Predicted value: 1, expected value: 1, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 1, expected value: 1, correct: True
# Predicted value: 1, expected value: 1, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 1, expected value: 1, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 1, expected value: 1, correct: True
# Predicted value: 2, expected value: 1, correct: False
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 1, expected value: 1, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 1, expected value: 1, correct: True
# Predicted value: 1, expected value: 1, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 2, expected value: 2, correct: True
# Predicted value: 0, expected value: 0, correct: True
# Predicted value: 0, expected value: 0, correct: True

# %%
accuracy = np.sum(y_hat == y_test) / len(y_hat)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9666666666666667
